# %% [markdown]
# <a href="https://colab.research.google.com/github/simha13/Diabetes-Prediction/blob/main/Diabetes_Prediction.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# ### **Imported libraries**

# %%
import numpy as np
import pandas as pd
from sklearn.model_selection import train_test_split
from sklearn.preprocessing import StandardScaler
from sklearn.svm import SVC
from sklearn.ensemble import RandomForestClassifier, ExtraTreesClassifier, AdaBoostClassifier, GradientBoostingClassifier, BaggingClassifier
from sklearn.tree import DecisionTreeClassifier
from sklearn.linear_model import Perceptron, LogisticRegression
from sklearn.discriminant_analysis import LinearDiscriminantAnalysis
from sklearn.neighbors import KNeighborsClassifier
from sklearn.naive_bayes import GaussianNB
from sklearn.metrics import accuracy_score

# %% [markdown]
# ### ***PIMA Diabetes Dataset***

# %% [markdown]
# Data Collection and Analysis

# %%
# loading the diabetes dataset to a pandas DataFrame
diabetes_dataset = pd.read_csv('/content/pima_diabetes.csv')

# %%
pd.read_csv
# Out:
# <function pandas.io.parsers.readers.read_csv(filepath_or_buffer: 'FilePath | ReadCsvBuffer[bytes] | ReadCsvBuffer[str]', *, sep: 'str | None | lib.NoDefault' = <no_default>, delimiter: 'str | None | lib.NoDefault' = None, header: "int | Sequence[int] | None | Literal['infer']" = 'infer', names: 'Sequence[Hashable] | None | lib.NoDefault' = <no_default>, index_col: 'IndexLabel | Literal[False] | None' = None, usecols=None, squeeze: 'bool | None' = None, prefix: 'str | lib.NoDefault' = <no_default>, mangle_dupe_cols: 'bool' = True, dtype: 'DtypeArg | None' = None, engine: 'CSVEngine | None' = None, converters=None, true_values=None, false_values=None, skipinitialspace: 'bool' = False, skiprows=None, skipfooter: 'int' = 0, nrows: 'int | None' = None, na_values=None, keep_default_na: 'bool' = True, na_filter: 'bool' = True, verbose: 'bool' = False, skip_blank_lines: 'bool' = True, parse_dates=None, infer_datetime_format: 'bool' = False, keep_date_col: 'bool' = False, date_parser=None, dayfirst: 'bool' = False, cache_dates: 'bool' = True, iterator: 'bool' = False, chunksize: 'int | None' = None, compression: 'CompressionOptions' = 'infer', thousands: 'str | None' = None, decimal: 'str' = '.', lineterminator: 'str | None' = None, quotechar: 'str' = '"', quoting: 'int' = 0, doublequote: 'bool' = True, escapechar: 'str | None' = None, comment: 'str | None' = None, encoding: 'str | None' = None, encoding_errors: 'str | None' = 'strict', dialect: 'str | csv.Dialect | None' = None, error_bad_lines: 'bool | None' = None, warn_bad_lines: 'bool | None' = None, on_bad_lines=None, delim_whitespace: 'bool' = False, low_memory=True, memory_map: 'bool' = False, float_precision: "Literal['high', 'legacy'] | None" = None, storage_options: 'StorageOptions' = None) -> 'DataFrame | TextFileReader'>

# %%
# printing the first 5 rows of the dataset
diabetes_dataset.head()
# Out:
#    Pregnancies  Glucose  BloodPressure  SkinThickness  Insulin   BMI  \
# 0            6      148             72             35        0  33.6
# 1            1       85             66             29        0  26.6
# 2            8      183             64              0        0  23.3
# 3            1       89             66             23       94  28.1
# 4            0      137             40             35      168  43.1
#
#    DiabetesPedigreeFunction  Age  Outcome
# 0                     0.627   50        1
# 1                     0.351   31        0
# 2                     0.672   32        1
# 3                     0.167   21        0
# 4                     2.288   33        1

# %%
# number of rows and Columns in this dataset
diabetes_dataset.shape
# Out:
# (768, 9)

# %%
# getting the statistical measures of the data
diabetes_dataset.describe()
# Out:
#        Pregnancies     Glucose  BloodPressure  SkinThickness     Insulin  \
# count   768.000000  768.000000     768.000000     768.000000  768.000000
# mean      3.845052  120.894531      69.105469      20.536458   79.799479
# std       3.369578   31.972618      19.355807      15.952218  115.244002
# min       0.000000    0.000000       0.000000       0.000000    0.000000
# 25%       1.000000   99.000000      62.000000       0.000000    0.000000
# 50%       3.000000  117.000000      72.000000      23.000000   30.500000
# 75%       6.000000  140.250000      80.000000      32.000000  127.250000
# max      17.000000  199.000000     122.000000      99.000000  846.000000
#
#               BMI  DiabetesPedigreeFunction         Age     Outcome
# count  768.000000                768.000000  768.000000  768.000000
# mean    31.992578                  0.471876   33.240885    0.348958
# std      7.884160                  0.331329   11.760232    0.476951
# min      0.000000                  0.078000   21.000000    0.000000
# 25%     27.300000                  0.243750   24.000000    0.000000
# 50%     32.000000                  0.372500   29.000000    0.000000
# 75%     36.600000                  0.626250   41.000000    1.000000
# max     67.100000                  2.420000   81.000000    1.000000

# %%
diabetes_dataset['Outcome'].value_counts()
# Out:
# 0    500
# 1    268
# Name: Outcome, dtype: int64

# %% [markdown]
# 0 --> Non-Diabetic
#
# 1 --> Diabetic

# %%
diabetes_dataset.groupby('Outcome').mean()
# Out:
#          Pregnancies     Glucose  BloodPressure  SkinThickness     Insulin  \
# Outcome
# 0           3.298000  109.980000      68.184000      19.664000   68.792000
# 1           4.865672  141.257463      70.824627      22.164179  100.335821
#
#                BMI  DiabetesPedigreeFunction        Age
# Outcome
# 0        30.304200                  0.429734  31.190000
# 1        35.142537                  0.550500  37.067164

# %%
# separating the data and labels
X = diabetes_dataset.drop(columns = 'Outcome', axis=1)
Y = diabetes_dataset['Outcome']

# %%
print(X)
# Out:
#      Pregnancies  Glucose  BloodPressure  SkinThickness  Insulin   BMI  \
# 0              6      148             72             35        0  33.6
# 1              1       85             66             29        0  26.6
# 2              8      183             64              0        0  23.3
# 3              1       89             66             23       94  28.1
# 4              0      137             40             35      168  43.1
# ..           ...      ...            ...            ...      ...   ...
# 763           10      101             76             48      180  32.9
# 764            2      122             70             27        0  36.8
# 765            5      121             72             23      112  26.2
# 766            1      126             60              0        0  30.1
# 767            1       93             70             31        0  30.4
#
#      DiabetesPedigreeFunction  Age
# 0                       0.627   50
# 1                       0.351   31
# 2                       0.672   32
# 3                       0.167   21
# 4                       2.288   33
# ..                        ...  ...
# 763                     0.171   63
# 764                     0.340   27
# 765                     0.245   30
# 766                     0.349   47
# 767                     0.315   23
#
# [768 rows x 8 columns]

# %%
print(Y)
# Out:
# 0      1
# 1      0
# 2      1
# 3      0
# 4      1
#       ..
# 763    0
# 764    0
# 765    0
# 766    1
# 767    0
# Name: Outcome, Length: 768, dtype: int64

# %% [markdown]
# Data Standardization

# %%
scaler = StandardScaler()

# %%
scaler.fit(X)
# Out:
# StandardScaler()

# %%
standardized_data = scaler.transform(X)

# %%
print(standardized_data)
# Out:
# [[ 0.63994726  0.84832379  0.14964075 ...  0.20401277  0.46849198
#    1.4259954 ]
#  [-0.84488505 -1.12339636 -0.16054575 ... -0.68442195 -0.36506078
#   -0.19067191]
#  [ 1.23388019  1.94372388 -0.26394125 ... -1.10325546  0.60439732
#   -0.10558415]
#  ...
#  [ 0.3429808   0.00330087  0.14964075 ... -0.73518964 -0.68519336
#   -0.27575966]
#  [-0.84488505  0.1597866  -0.47073225 ... -0.24020459 -0.37110101
#    1.17073215]
#  [-0.84488505 -0.8730192   0.04624525 ... -0.20212881 -0.47378505
#   -0.87137393]]

# %%
X = standardized_data
Y = diabetes_dataset['Outcome']

# %%
print(X)
print(Y)
# Out:
# [[ 0.63994726  0.84832379  0.14964075 ...  0.20401277  0.46849198
#    1.4259954 ]
#  [-0.84488505 -1.12339636 -0.16054575 ... -0.68442195 -0.36506078
#   -0.19067191]
#  [ 1.23388019  1.94372388 -0.26394125 ... -1.10325546  0.60439732
#   -0.10558415]
#  ...
#  [ 0.3429808   0.00330087  0.14964075 ... -0.73518964 -0.68519336
#   -0.27575966]
#  [-0.84488505  0.1597866  -0.47073225 ... -0.24020459 -0.37110101
#    1.17073215]
#  [-0.84488505 -0.8730192   0.04624525 ... -0.20212881 -0.47378505
#   -0.87137393]]
# 0      1
# 1      0
# 2      1
# 3      0
# 4      1
#       ..
# 763    0
# 764    0
# 765    0
# 766    1
# 767    0
# Name: Outcome, Length: 768, dtype: int64

# %% [markdown]
# Train Test Split

# %%
X_train, X_test, Y_train, Y_test = train_test_split(X,Y, test_size = 0.2, stratify=Y, random_state=2)

# %%
print(X.shape, X_train.shape, X_test.shape)
# Out:
# (768, 8) (614, 8) (154, 8)

# %% [markdown]
# Training the Model

# %%
# Define classifiers
classifiers = {
    'Support Vector Classifier': SVC(),
    'Random Forest Classifier': RandomForestClassifier(),
    'Extra Tree Classifier': ExtraTreesClassifier(),
    'AdaBoost Classifier': AdaBoostClassifier(),
    'Decision Tree Classifier': DecisionTreeClassifier(),
    'Perceptron': Perceptron(),
    'Linear Discriminant Analysis': LinearDiscriminantAnalysis(),
    'Logistic Regression': LogisticRegression(),
    'K-Nearest Neighbour': KNeighborsClassifier(),
    'Gaussian Naïve Bayes': GaussianNB(),
    'Bagging Classifier': BaggingClassifier(),
    'Gradient Boost Classifier': GradientBoostingClassifier()
}
# Out:
# Support Vector Classifier Accuracy: 0.73
# Random Forest Classifier Accuracy: 0.75
# Extra Tree Classifier Accuracy: 0.75
# AdaBoost Classifier Accuracy: 0.71
# Decision Tree Classifier Accuracy: 0.70
# Perceptron Accuracy: 0.75
# Linear Discriminant Analysis Accuracy: 0.75
# Logistic Regression Accuracy: 0.76
# K-Nearest Neighbour Accuracy: 0.72
# Gaussian Naïve Bayes Accuracy: 0.77
# Bagging Classifier Accuracy: 0.75
# Gradient Boost Classifier Accuracy: 0.71

# %% [markdown]
# Model Evaluation

# %% [markdown]
# Accuracy Score

# %%
# Train and evaluate each classifier
for name, classifier in classifiers.items():
    classifier.fit(X_train, Y_train)
    y_pred = classifier.predict(X_test)
    accuracy = accuracy_score(Y_test, y_pred)
    print(f'{name} Accuracy: {accuracy:.2f}')
# Out:
# Support Vector Classifier Accuracy: 0.73
# Random Forest Classifier Accuracy: 0.76
# Extra Tree Classifier Accuracy: 0.73
# AdaBoost Classifier Accuracy: 0.71
# Decision Tree Classifier Accuracy: 0.69
# Perceptron Accuracy: 0.75
# Linear Discriminant Analysis Accuracy: 0.75
# Logistic Regression Accuracy: 0.76
# K-Nearest Neighbour Accuracy: 0.72
# Gaussian Naïve Bayes Accuracy: 0.77
# Bagging Classifier Accuracy: 0.68
# Gradient Boost Classifier Accuracy: 0.71

# %% [markdown]
# Making a Predictive System

# %%
input_data = (5,166,72,19,175,25.8,0.587,51)

# changing the input_data to numpy array
input_data_as_numpy_array = np.asarray(input_data)

# reshape the array as we are predicting for one instance
input_data_reshaped = input_data_as_numpy_array.reshape(1,-1)

# standardize the input data
std_data = scaler.transform(input_data_reshaped)
print(std_data)

prediction = classifier.predict(std_data)
print(prediction)

if (prediction[0] == 0):
  print('The person is not diabetic')
else:
  print('The person is diabetic')
# Out:
# [[ 0.3429808   1.41167241  0.14964075 -0.09637905  0.82661621 -0.78595734
#    0.34768723  1.51108316]]
# [1]
# The person is diabetic
# /usr/local/lib/python3.10/dist-packages/sklearn/base.py:439: UserWarning: X does not have valid feature names, but StandardScaler was fitted with feature names
#   warnings.warn(

# %% [markdown]
# ### ***Diabetes Dataset***

# %% [markdown]
# Data Collection and Analysis

# %%
# loading the diabetes dataset to a pandas DataFrame
diabetes_dataset = pd.read_csv('/content/diabetes_prediction_dataset.csv')

# %%
pd.read_csv
# Out:
# <function pandas.io.parsers.readers.read_csv(filepath_or_buffer: 'FilePath | ReadCsvBuffer[bytes] | ReadCsvBuffer[str]', *, sep: 'str | None | lib.NoDefault' = <no_default>, delimiter: 'str | None | lib.NoDefault' = None, header: "int | Sequence[int] | None | Literal['infer']" = 'infer', names: 'Sequence[Hashable] | None | lib.NoDefault' = <no_default>, index_col: 'IndexLabel | Literal[False] | None' = None, usecols=None, squeeze: 'bool | None' = None, prefix: 'str | lib.NoDefault' = <no_default>, mangle_dupe_cols: 'bool' = True, dtype: 'DtypeArg | None' = None, engine: 'CSVEngine | None' = None, converters=None, true_values=None, false_values=None, skipinitialspace: 'bool' = False, skiprows=None, skipfooter: 'int' = 0, nrows: 'int | None' = None, na_values=None, keep_default_na: 'bool' = True, na_filter: 'bool' = True, verbose: 'bool' = False, skip_blank_lines: 'bool' = True, parse_dates=None, infer_datetime_format: 'bool' = False, keep_date_col: 'bool' = False, date_parser=None, dayfirst: 'bool' = False, cache_dates: 'bool' = True, iterator: 'bool' = False, chunksize: 'int | None' = None, compression: 'CompressionOptions' = 'infer', thousands: 'str | None' = None, decimal: 'str' = '.', lineterminator: 'str | None' = None, quotechar: 'str' = '"', quoting: 'int' = 0, doublequote: 'bool' = True, escapechar: 'str | None' = None, comment: 'str | None' = None, encoding: 'str | None' = None, encoding_errors: 'str | None' = 'strict', dialect: 'str | csv.Dialect | None' = None, error_bad_lines: 'bool | None' = None, warn_bad_lines: 'bool | None' = None, on_bad_lines=None, delim_whitespace: 'bool' = False, low_memory=True, memory_map: 'bool' = False, float_precision: "Literal['high', 'legacy'] | None" = None, storage_options: 'StorageOptions' = None) -> 'DataFrame | TextFileReader'>

# %%
# printing the first 5 rows of the dataset
diabetes_dataset.head()
# Out:
#    gender   age  hypertension  heart_disease  smoking_history    bmi  \
# 0       0  80.0             0              1               10  25.19
# 1       0  54.0             0              0                8  27.32
# 2       1  28.0             0              0               10  27.32
# 3       0  36.0             0              0                6  23.45
# 4       1  76.0             1              1                6  20.14
#
#    HbA1c_level  blood_glucose_level  diabetes
# 0          6.6                  140         0
# 1          6.6                   80         0
# 2          5.7                  158         0
# 3          5.0                  155         0
# 4          4.8                  155         0

# %%
# number of rows and Columns in this dataset
diabetes_dataset.shape
# Out:
# (100000, 9)

# %%
# getting the statistical measures of the data
diabetes_dataset.describe()
# Out:
#               gender            age  hypertension  heart_disease  \
# count  100000.000000  100000.000000  100000.00000  100000.000000
# mean        0.414660      41.885856       0.07485       0.039420
# std         0.493031      22.516840       0.26315       0.194593
# min         0.000000       0.080000       0.00000       0.000000
# 25%         0.000000      24.000000       0.00000       0.000000
# 50%         0.000000      43.000000       0.00000       0.000000
# 75%         1.000000      60.000000       0.00000       0.000000
# max         2.000000      80.000000       1.00000       1.000000
#
#        smoking_history            bmi    HbA1c_level  blood_glucose_level  \
# count    100000.000000  100000.000000  100000.000000        100000.000000
# mean          8.625310      27.320767       5.527507           138.058060
# std           1.304758       6.636783       1.070672            40.708136
# min           6.000000      10.010000       3.500000            80.000000
# 25%           8.000000      23.630000       4.800000           100.000000
# 50%           8.000000      27.320000       5.800000           140.000000
# 75%          10.000000      29.580000       6.200000           159.000000
# max          10.000000      95.690000       9.000000           300.000000
#
#             diabetes
# count  100000.000000
# mean        0.085000
# std         0.278883
# min         0.000000
# 25%         0.000000
# 50%         0.000000
# 75%         0.000000
# max         1.000000

# %%
diabetes_dataset['diabetes'].value_counts()
# Out:
# 0    91500
# 1     8500
# Name: diabetes, dtype: int64

# %% [markdown]
# 0 --> Non-Diabetic
#
# 1 --> Diabetic

# %%
diabetes_dataset.groupby('diabetes').mean()
# Out:
#             gender        age  hypertension  heart_disease  smoking_history  \
# diabetes
# 0         0.409038  40.115187      0.058984       0.029235         8.610831
# 1         0.475176  60.946588      0.245647       0.149059         8.781176
#
#                 bmi  HbA1c_level  blood_glucose_level
# diabetes
# 0         26.887163     5.396761           132.852470
# 1         31.988382     6.934953           194.094706

# %%
# separating the data and labels
X = diabetes_dataset.drop(columns = 'diabetes', axis=1)
Y = diabetes_dataset['diabetes']

# %%
print(X)
# Out:
#        gender   age  hypertension  heart_disease  smoking_history    bmi  \
# 0           0  80.0             0              1               10  25.19
# 1           0  54.0             0              0                8  27.32
# 2           1  28.0             0              0               10  27.32
# 3           0  36.0             0              0                6  23.45
# 4           1  76.0             1              1                6  20.14
# ...       ...   ...           ...            ...              ...    ...
# 99995       0  80.0             0              0                8  27.32
# 99996       0   2.0             0              0                8  17.37
# 99997       1  66.0             0              0                9  27.83
# 99998       0  24.0             0              0               10  35.42
# 99999       0  57.0             0              0                6  22.43
#
#        HbA1c_level  blood_glucose_level
# 0              6.6                  140
# 1              6.6                   80
# 2              5.7                  158
# 3              5.0                  155
# 4              4.8                  155
# ...            ...                  ...
# 99995          6.2                   90
# 99996          6.5                  100
# 99997          5.7                  155
# 99998          4.0                  100
# 99999          6.6                   90
#
# [100000 rows x 8 columns]

# %%
print(Y)
# Out:
# 0        0
# 1        0
# 2        0
# 3        0
# 4        0
#         ..
# 99995    0
# 99996    0
# 99997    0
# 99998    0
# 99999    0
# Name: diabetes, Length: 100000, dtype: int64

# %% [markdown]
# Data Standardization

# %%
scaler = StandardScaler()

# %%
scaler.fit(X)
# Out:
# StandardScaler()

# %%
standardized_data = scaler.transform(X)

# %%
print(standardized_data)
# Out:
# [[-8.41046744e-01  1.69270354e+00 -2.84439447e-01 ... -3.21055792e-01
#    1.00170572e+00  4.77042159e-02]
#  [-8.41046744e-01  5.38006427e-01 -2.84439447e-01 ... -1.15583678e-04
#    1.00170572e+00 -1.42620999e+00]
#  [ 1.18723364e+00 -6.16690686e-01 -2.84439447e-01 ... -1.15583678e-04
#    1.61108022e-01  4.89878478e-01]
#  ...
#  [ 1.18723364e+00  1.07094356e+00 -2.84439447e-01 ...  7.67292549e-02
#    1.61108022e-01  4.16182767e-01]
#  [-8.41046744e-01 -7.94336396e-01 -2.84439447e-01 ...  1.22036126e+00
#   -1.42668764e+00 -9.34905254e-01]
#  [-8.41046744e-01  6.71240710e-01 -2.84439447e-01 ... -7.36921977e-01
#    1.00170572e+00 -1.18055762e+00]]

# %%
X = standardized_data
Y = diabetes_dataset['diabetes']

# %%
print(X)
print(Y)
# Out:
# [[-8.41046744e-01  1.69270354e+00 -2.84439447e-01 ... -3.21055792e-01
#    1.00170572e+00  4.77042159e-02]
#  [-8.41046744e-01  5.38006427e-01 -2.84439447e-01 ... -1.15583678e-04
#    1.00170572e+00 -1.42620999e+00]
#  [ 1.18723364e+00 -6.16690686e-01 -2.84439447e-01 ... -1.15583678e-04
#    1.61108022e-01  4.89878478e-01]
#  ...
#  [ 1.18723364e+00  1.07094356e+00 -2.84439447e-01 ...  7.67292549e-02
#    1.61108022e-01  4.16182767e-01]
#  [-8.41046744e-01 -7.94336396e-01 -2.84439447e-01 ...  1.22036126e+00
#   -1.42668764e+00 -9.34905254e-01]
#  [-8.41046744e-01  6.71240710e-01 -2.84439447e-01 ... -7.36921977e-01
#    1.00170572e+00 -1.18055762e+00]]
# 0        0
# 1        0
# 2        0
# 3        0
# 4        0
#         ..
# 99995    0
# 99996    0
# 99997    0
# 99998    0
# 99999    0
# Name: diabetes, Length: 100000, dtype: int64

# %% [markdown]
# Train Test Split

# %%
X_train, X_test, Y_train, Y_test = train_test_split(X, Y, test_size=0.2, stratify=Y, random_state=2)

# %%
print(X.shape, X_train.shape, X_test.shape)
# Out:
# (100000, 8) (80000, 8) (20000, 8)

# %% [markdown]
# Training the Model

# %%
# Define classifiers
classifiers = {
    'Support Vector Classifier': SVC(),
    'Random Forest Classifier': RandomForestClassifier(),
    'Extra Tree Classifier': ExtraTreesClassifier(),
    'AdaBoost Classifier': AdaBoostClassifier(),
    'Decision Tree Classifier': DecisionTreeClassifier(),
    'Perceptron': Perceptron(),
    'Linear Discriminant Analysis': LinearDiscriminantAnalysis(),
    'Logistic Regression': LogisticRegression(),
    'K-Nearest Neighbour': KNeighborsClassifier(),
    'Gaussian Naïve Bayes': GaussianNB(),
    'Bagging Classifier': BaggingClassifier(),
    'Gradient Boost Classifier': GradientBoostingClassifier()
}

# %% [markdown]
# Model Evaluation

# %% [markdown]
# Accuracy Score

# %%
# Train and evaluate each classifier
for name, classifier in classifiers.items():
    classifier.fit(X_train, Y_train)
    y_pred = classifier.predict(X_test)
    accuracy = accuracy_score(Y_test, y_pred)
    print(f'{name} Accuracy: {accuracy:.2f}')
# Out:
# Support Vector Classifier Accuracy: 0.96
# Random Forest Classifier Accuracy: 0.97
# Extra Tree Classifier Accuracy: 0.97
# AdaBoost Classifier Accuracy: 0.97
# Decision Tree Classifier Accuracy: 0.95
# Perceptron Accuracy: 0.95
# Linear Discriminant Analysis Accuracy: 0.96
# Logistic Regression Accuracy: 0.96
# K-Nearest Neighbour Accuracy: 0.96
# Gaussian Naïve Bayes Accuracy: 0.91
# Bagging Classifier Accuracy: 0.97
# Gradient Boost Classifier Accuracy: 0.97
